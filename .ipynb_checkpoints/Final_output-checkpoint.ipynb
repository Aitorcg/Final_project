# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_columns", 60)
db= pd.read_csv("databases/houses_Madrid_2.csv")
db=db.drop(['Unnamed: 0'],axis=1)
db.head()
# Out:
#       id                                              title  \
# 0  21742              Piso en venta en calle de Godella, 64
# 1  21741   Piso en venta en calle de la del Manojo de Rosas
# 2  21740               Piso en venta en calle del Talco, 68
# 3  21739               Piso en venta en calle Pedro Jiménez
# 4  21738  Piso en venta en carretera de Villaverde a Val...
#
#             neighborhood  sq_mt_built  n_rooms  n_bathrooms  n_floors floor  \
# 0  San Cristóbal, Madrid         64.0      2.0          1.0       1.0     3
# 1    Los Ángeles, Madrid         70.0      3.0          1.0       1.0     4
# 2     San Andrés, Madrid         94.0      2.0          2.0       1.0     1
# 3     San Andrés, Madrid         64.0      2.0          1.0       1.0  Bajo
# 4    Los Rosales, Madrid        108.0      2.0          2.0       1.0     4
#
#    neighborhood_id operation  rent_price  buy_price       house_type_id  \
# ...

# %% [markdown]
# ### Giving the output to the client

# %% [markdown]
# - ### The client has asked us for the following products:

# %%
1.# a house in the center for less than 120.000€ and a high profitability
# Out:
# 1.0

# %%
#With our code, and the variables you ask for, we suggest to buy one of these houses

# %%
db[(db.district=='Centro') & (db.buy_price < 120000) & (db.year_profit >6)]
# Out:
#          id                                            title  \
# 17614  4125     Estudio en venta en calle del Amparo, Madrid
# 17658  4081             Piso en venta en calle del Ave María
# 17838  3901            Piso en venta en Lavapiés-Embajadores
# 18243  3496             Estudio en venta en calle del Amparo
# 18643  3096  Piso en venta en calle de Bernardo López García
# 18670  3069                Estudio en venta en calle Salitre
# 18786  2953             Estudio en venta en calle del Amparo
# 18849  2890                Piso en venta en calle del Amparo
# 18994  2745                   Piso en venta en calle Salitre
#
#                        neighborhood  sq_mt_built  n_rooms  n_bathrooms  \
# 17614  Lavapiés-Embajadores, Madrid         15.0      0.0          1.0
# 17658  Lavapiés-Embajadores, Madrid         40.0      1.0          1.0
# 17838                Centro, Madrid         71.0      2.0          1.0
# ...

# %%
2.#a house with pool and garden for less than 1.500€ per square meter and a max of 300.000€

# %%
#With our code, and the variables you ask for, we suggest to buy one of these houses

# %%
db[(db.price_sqm < 1500) & (db.has_pool ==True) & (db.has_garden ==True) & (db.buy_price < 350000)]
# Out:
#          id                                              title  \
# 880   20862   Chalet adosado en venta en calle Ferenc Puska...
# 1122  20620   Chalet adosado en venta en calle Ferenc Puska...
#
#                                neighborhood  sq_mt_built  n_rooms  \
# 880   El Cañaveral - Los Berrocales, Madrid        248.0      4.0
# 1122  El Cañaveral - Los Berrocales, Madrid        248.0      4.0
#
#       n_bathrooms  n_floors          floor  neighborhood_id operation  \
# 880           3.0       3.0  not_specified              126      sale
# 1122          3.0       3.0  not_specified              126      sale
#
#       rent_price  buy_price               house_type_id  is_renewal_needed  \
# 880       1318.0   348000.0  HouseType 2: Casa o chalet              False
# 1122      1318.0   348000.0  HouseType 2: Casa o chalet              False
#
#       is_new_development     built_year has_central_heating  \
# 880                 True  not_specified       not_specified
# ...

# %%
3. #a house that doesn`t need to be renewed and for less than 60.000 euros

# %%
#With our code, and the variables you ask for, we suggest to buy one of these houses

# %%
db[(db.is_renewal_needed ==False) & (db.buy_price < 60000)]
# Out:
#           id                                             title  \
# 264    21478          Piso en venta en calle de Rocafort, 14 j
# 1821   19921       Estudio en venta en calle de Puentelarra, 7
# 2430   19312                            Piso en venta en Zofío
# 3248   18494            Estudio en venta en calle Juan Pantoja
# 4839   16903         Piso en venta en calle del Doctor Bellido
# 4908   16834      Piso en venta en calle del Puerto de Arlabán
# 5206   16536  Piso en venta en calle del Puerto de Arlabán, 88
# 5284   16458   Estudio en venta en calle del Puerto de Arlabán
# 5313   16429              Piso en venta en calle Emilio Raboso
# 5319   16423       Piso en venta en calle de García Llamas, 19
# 5650   16092           Estudio en venta en calle Emilio Ortuño
# 21155    584               Piso en venta en calle de la Laguna
#
#                 neighborhood  sq_mt_built  n_rooms  n_bathrooms  n_floors  \
# ...
