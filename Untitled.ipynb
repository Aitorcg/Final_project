# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import pandas as pd
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
from urllib.request import urlopen
# import random
import re
# import scrapy
import numpy as np
pip install xlrd

# %%
pd.set_option("display.max_columns", 60)
db= pd.read_csv("houses_Madrid.csv")
db
# Out:
#        Unnamed: 0     id                                              title  \
# 0               0  21742              Piso en venta en calle de Godella, 64
# 1               1  21741   Piso en venta en calle de la del Manojo de Rosas
# 2               2  21740               Piso en venta en calle del Talco, 68
# 3               3  21739               Piso en venta en calle Pedro Jiménez
# 4               4  21738  Piso en venta en carretera de Villaverde a Val...
# ...           ...    ...                                                ...
# 21737       21737      5       Ático en venta en Casco Histórico de Barajas
# 21738       21738      4  Piso en venta en Urb. Campo de las Naciones - ...
# 21739       21739      3  Piso en venta en Campo de las Naciones-Corralejos
# 21740       21740      2      Chalet adosado en venta en calle Burriana, 12
# 21741       21741      1             Piso en venta en calle San Epifanio, 9
#
#                                        subtitle  sq_mt_built  sq_mt_useful  \
# 0                         San Cristóbal, Madrid         64.0          60.0
# 1                           Los Ángeles, Madrid         70.0           NaN
# 2                            San Andrés, Madrid         94.0          54.0
# 3                            San Andrés, Madrid         64.0           NaN
# 4                           Los Rosales, Madrid        108.0          90.0
# ...                                         ...          ...           ...
# 21737                           Barajas, Madrid         78.0           NaN
# 21738                           Barajas, Madrid         96.0          83.0
# 21739                           Barajas, Madrid        175.0           NaN
# 21740  Campo de las Naciones-Corralejos, Madrid        289.0           NaN
# 21741                          Imperial, Madrid         72.0           NaN
#
#        n_rooms  n_bathrooms  n_floors  sq_mt_allotment  latitude  longitude  \
# 0            2          1.0       NaN              NaN       NaN        NaN
# 1            3          1.0       NaN              NaN       NaN        NaN
# 2            2          2.0       NaN              NaN       NaN        NaN
# 3            2          1.0       NaN              NaN       NaN        NaN
# 4            2          2.0       NaN              NaN       NaN        NaN
# ...        ...          ...       ...              ...       ...        ...
# 21737        2          2.0       NaN              NaN       NaN        NaN
# 21738        2          2.0       NaN              NaN       NaN        NaN
# 21739        4          2.0       NaN              NaN       NaN        NaN
# 21740        4          3.0       3.0            304.0       NaN        NaN
# 21741        2          2.0       NaN              NaN       NaN        NaN
#
#                                    raw_address  is_exact_address_hidden  \
# 0                         Calle de Godella, 64                    False
# 1              Calle de la del Manojo de Rosas                     True
# 2                          Calle del Talco, 68                    False
# 3                          Calle Pedro Jiménez                     True
# 4           Carretera de Villaverde a Vallecas                     True
# ...                                        ...                      ...
# 21737                                      NaN                     True
# 21738  Urb. Campo de las Naciones - Corralejos                     True
# 21739                                      NaN                     True
# 21740                       Calle Burriana, 12                    False
# 21741                    Calle San Epifanio, 9                    False
#
#                                    street_name street_number  portal floor  \
# 0                             Calle de Godella            64     NaN     3
# 1              Calle de la del Manojo de Rosas           NaN     NaN     4
# 2                              Calle del Talco            68     NaN     1
# 3                          Calle Pedro Jiménez           NaN     NaN  Bajo
# 4           Carretera de Villaverde a Vallecas           NaN     NaN     4
# ...                                        ...           ...     ...   ...
# 21737                                      NaN           NaN     NaN     4
# 21738  Urb. Campo de las Naciones - Corralejos           NaN     NaN     3
# 21739                                      NaN           NaN     NaN  Bajo
# 21740                           Calle Burriana            12     NaN   NaN
# 21741                       Calle San Epifanio             9     NaN   NaN
#
#       is_floor_under  door                                    neighborhood_id  \
# 0              False   NaN  Neighborhood 135: San Cristóbal (1308.89 €/m2)...
# 1              False   NaN  Neighborhood 132: Los Ángeles (1796.68 €/m2) -...
# 2              False   NaN  Neighborhood 134: San Andrés (1617.18 €/m2) - ...
# 3               True   NaN  Neighborhood 134: San Andrés (1617.18 €/m2) - ...
# 4              False   NaN  Neighborhood 133: Los Rosales (1827.79 €/m2) -...
# ...              ...   ...                                                ...
# 21737          False   NaN  Neighborhood 10: Casco Histórico de Barajas (3...
# 21738          False   NaN  Neighborhood 9: Campo de las Naciones-Corralej...
# 21739           True   NaN  Neighborhood 9: Campo de las Naciones-Corralej...
# 21740          False   NaN  Neighborhood 9: Campo de las Naciones-Corralej...
# 21741            NaN   NaN  Neighborhood 3: Imperial (4098.59 €/m2) - Dist...
#
#       operation  rent_price  rent_price_by_area  is_rent_price_known  \
# 0          sale         471                 NaN                False
# 1          sale         666                 NaN                False
# 2          sale         722                 NaN                False
# 3          sale         583                 NaN                False
# 4          sale        1094                 NaN                False
# ...         ...         ...                 ...                  ...
# 21737      sale        1323                 NaN                False
# 21738      sale        1496                 NaN                False
# 21739      sale        2081                 NaN                False
# 21740      sale        2115                 NaN                False
# 21741      sale        1494                 NaN                False
#
#        buy_price  buy_price_by_area  is_buy_price_known  \
# 0          85000               1328                True
# 1         129900               1856                True
# 2         144247               1535                True
# 3         109900               1717                True
# 4         260000               2407                True
# ...          ...                ...                 ...
# 21737     350000               4487                True
# 21738     425000               4427                True
# 21739     680000               3886                True
# 21740     695000               2405                True
# 21741     424000               5889                True
#
#                     house_type_id  is_renewal_needed is_new_development  \
# 0              HouseType 1: Pisos              False              False
# 1              HouseType 1: Pisos               True              False
# 2              HouseType 1: Pisos              False              False
# 3              HouseType 1: Pisos              False              False
# 4              HouseType 1: Pisos              False              False
# ...                           ...                ...                ...
# 21737         HouseType 5: Áticos              False              False
# 21738          HouseType 1: Pisos              False              False
# 21739          HouseType 1: Pisos              False              False
# 21740  HouseType 2: Casa o chalet              False              False
# 21741          HouseType 1: Pisos              False               True
#
#        built_year has_central_heating has_individual_heating  \
# 0          1960.0                 NaN                    NaN
# 1             NaN                 NaN                    NaN
# 2             NaN               False                   True
# 3          1955.0                 NaN                    NaN
# 4          2003.0                 NaN                    NaN
# ...           ...                 ...                    ...
# 21737      2020.0               False                   True
# 21738      2002.0               False                   True
# 21739      2002.0               False                   True
# 21740      1981.0                 NaN                    NaN
# 21741         NaN                 NaN                    NaN
#
#        are_pets_allowed has_ac has_fitted_wardrobes has_lift is_exterior  \
# 0                   NaN   True                  NaN    False        True
# 1                   NaN    NaN                 True     True        True
# 2                   NaN    NaN                 True     True        True
# 3                   NaN    NaN                  NaN     True        True
# 4                   NaN   True                 True     True        True
# ...                 ...    ...                  ...      ...         ...
# 21737               NaN   True                 True     True        True
# 21738               NaN   True                 True     True        True
# 21739               NaN   True                 True    False        True
# 21740               NaN   True                 True      NaN         NaN
# 21741               NaN    NaN                  NaN     True        True
#
#       has_garden has_pool has_terrace has_balcony has_storage_room  \
# 0            NaN      NaN         NaN         NaN              NaN
# 1            NaN      NaN        True         NaN              NaN
# 2            NaN      NaN         NaN         NaN             True
# 3            NaN      NaN         NaN         NaN             True
# 4            NaN     True         NaN         NaN             True
# ...          ...      ...         ...         ...              ...
# 21737        NaN      NaN         NaN         NaN             True
# 21738        NaN     True         NaN         NaN             True
# 21739        NaN     True        True         NaN             True
# 21740       True      NaN        True        True             True
# 21741        NaN     True        True         NaN              NaN
#
#        is_furnished  is_kitchen_equipped is_accessible has_green_zones  \
# 0               NaN                  NaN           NaN             NaN
# 1               NaN                  NaN           NaN             NaN
# 2               NaN                  NaN           NaN             NaN
# 3               NaN                  NaN          True             NaN
# 4               NaN                  NaN           NaN            True
# ...             ...                  ...           ...             ...
# 21737           NaN                  NaN           NaN             NaN
# 21738           NaN                  NaN           NaN            True
# 21739           NaN                  NaN           NaN             NaN
# 21740           NaN                  NaN           NaN             NaN
# 21741           NaN                  NaN           NaN             NaN
#
#       energy_certificate  has_parking  has_private_parking  \
# 0                      D        False                  NaN
# 1             en trámite        False                  NaN
# 2            no indicado        False                  NaN
# 3             en trámite        False                  NaN
# 4             en trámite         True                  NaN
# ...                  ...          ...                  ...
# 21737         en trámite         True                  NaN
# 21738         en trámite         True                  NaN
# 21739                  E         True                  NaN
# 21740         en trámite         True                  NaN
# 21741                  A         True                  NaN
#
#        has_public_parking is_parking_included_in_price  parking_price  \
# 0                     NaN                          NaN            NaN
# 1                     NaN                          NaN            NaN
# 2                     NaN                          NaN            NaN
# 3                     NaN                          NaN            NaN
# 4                     NaN                         True            0.0
# ...                   ...                          ...            ...
# 21737                 NaN                         True            0.0
# 21738                 NaN                         True            0.0
# 21739                 NaN                         True            0.0
# 21740                 NaN                         True            0.0
# 21741                 NaN                         True            0.0
#
#       is_orientation_north is_orientation_west is_orientation_south  \
# 0                    False                True                False
# 1                      NaN                 NaN                  NaN
# 2                      NaN                 NaN                  NaN
# 3                    False               False                 True
# 4                     True                True                 True
# ...                    ...                 ...                  ...
# 21737                  NaN                 NaN                  NaN
# 21738                False                True                 True
# 21739                  NaN                 NaN                  NaN
# 21740                False               False                 True
# 21741                  NaN                 NaN                  NaN
#
#       is_orientation_east
# 0                   False
# 1                     NaN
# 2                     NaN
# 3                   False
# 4                    True
# ...                   ...
# 21737                 NaN
# 21738                True
# 21739                 NaN
# 21740               False
# 21741                 NaN
#
# [21742 rows x 58 columns]

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21742 entries, 0 to 21741
# Data columns (total 58 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    21742 non-null  int64
#  1   id                            21742 non-null  int64
#  2   title                         21742 non-null  object
#  3   subtitle                      21742 non-null  object
#  4   sq_mt_built                   21616 non-null  float64
#  5   sq_mt_useful                  8228 non-null   float64
#  6   n_rooms                       21742 non-null  int64
#  7   n_bathrooms                   21726 non-null  float64
#  8   n_floors                      1437 non-null   float64
#  9   sq_mt_allotment               1432 non-null   float64
#  10  latitude                      0 non-null      float64
#  11  longitude                     0 non-null      float64
#  12  raw_address                   16277 non-null  object
#  13  is_exact_address_hidden       21742 non-null  bool
#  14  street_name                   15837 non-null  object
#  15  street_number                 6300 non-null   object
#  16  portal                        0 non-null      float64
#  17  floor                         19135 non-null  object
#  18  is_floor_under                20572 non-null  object
#  19  door                          0 non-null      float64
#  20  neighborhood_id               21742 non-null  object
#  21  operation                     21742 non-null  object
#  22  rent_price                    21742 non-null  int64
#  23  rent_price_by_area            0 non-null      float64
#  24  is_rent_price_known           21742 non-null  bool
#  25  buy_price                     21742 non-null  int64
#  26  buy_price_by_area             21742 non-null  int64
#  27  is_buy_price_known            21742 non-null  bool
#  28  house_type_id                 21351 non-null  object
#  29  is_renewal_needed             21742 non-null  bool
#  30  is_new_development            20750 non-null  object
#  31  built_year                    10000 non-null  float64
#  32  has_central_heating           13608 non-null  object
#  33  has_individual_heating        13608 non-null  object
#  34  are_pets_allowed              0 non-null      float64
#  35  has_ac                        11211 non-null  object
#  36  has_fitted_wardrobes          13399 non-null  object
#  37  has_lift                      19356 non-null  object
#  38  is_exterior                   18699 non-null  object
#  39  has_garden                    1556 non-null   object
#  40  has_pool                      5171 non-null   object
#  41  has_terrace                   9548 non-null   object
#  42  has_balcony                   3321 non-null   object
#  43  has_storage_room              7698 non-null   object
#  44  is_furnished                  0 non-null      float64
#  45  is_kitchen_equipped           0 non-null      float64
#  46  is_accessible                 4074 non-null   object
#  47  has_green_zones               4057 non-null   object
#  48  energy_certificate            21742 non-null  object
#  49  has_parking                   21742 non-null  bool
#  50  has_private_parking           0 non-null      float64
#  51  has_public_parking            0 non-null      float64
#  52  is_parking_included_in_price  7719 non-null   object
#  53  parking_price                 7719 non-null   float64
#  54  is_orientation_north          11358 non-null  object
#  55  is_orientation_west           11358 non-null  object
#  56  is_orientation_south          11358 non-null  object
#  57  is_orientation_east           11358 non-null  object
# dtypes: bool(5), float64(17), int64(6), object(30)
# memory usage: 8.9+ MB

# %%
db.isnull().sum()
# Out:
# Unnamed: 0                          0
# id                                  0
# title                               0
# subtitle                            0
# sq_mt_built                       126
# sq_mt_useful                    13514
# n_rooms                             0
# n_bathrooms                        16
# n_floors                        20305
# sq_mt_allotment                 20310
# latitude                        21742
# longitude                       21742
# raw_address                      5465
# is_exact_address_hidden             0
# street_name                      5905
# street_number                   15442
# portal                          21742
# floor                            2607
# is_floor_under                   1170
# door                            21742
# neighborhood_id                     0
# operation                           0
# rent_price                          0
# rent_price_by_area              21742
# is_rent_price_known                 0
# buy_price                           0
# buy_price_by_area                   0
# is_buy_price_known                  0
# house_type_id                     391
# is_renewal_needed                   0
# is_new_development                992
# built_year                      11742
# has_central_heating              8134
# has_individual_heating           8134
# are_pets_allowed                21742
# has_ac                          10531
# has_fitted_wardrobes             8343
# has_lift                         2386
# is_exterior                      3043
# has_garden                      20186
# has_pool                        16571
# has_terrace                     12194
# has_balcony                     18421
# has_storage_room                14044
# is_furnished                    21742
# is_kitchen_equipped             21742
# is_accessible                   17668
# has_green_zones                 17685
# energy_certificate                  0
# has_parking                         0
# has_private_parking             21742
# has_public_parking              21742
# is_parking_included_in_price    14023
# parking_price                   14023
# is_orientation_north            10384
# is_orientation_west             10384
# is_orientation_south            10384
# is_orientation_east             10384
# dtype: int64

# %%
db.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'subtitle', 'sq_mt_built', 'sq_mt_useful',
#        'n_rooms', 'n_bathrooms', 'n_floors', 'sq_mt_allotment', 'latitude',
#        'longitude', 'raw_address', 'is_exact_address_hidden', 'street_name',
#        'street_number', 'portal', 'floor', 'is_floor_under', 'door',
#        'neighborhood_id', 'operation', 'rent_price', 'rent_price_by_area',
#        'is_rent_price_known', 'buy_price', 'buy_price_by_area',
#        'is_buy_price_known', 'house_type_id', 'is_renewal_needed',
#        'is_new_development', 'built_year', 'has_central_heating',
#        'has_individual_heating', 'are_pets_allowed', 'has_ac',
#        'has_fitted_wardrobes', 'has_lift', 'is_exterior', 'has_garden',
#        'has_pool', 'has_terrace', 'has_balcony', 'has_storage_room',
#        'is_furnished', 'is_kitchen_equipped', 'is_accessible',
#        'has_green_zones', 'energy_certificate', 'has_parking',
#        'has_private_parking', 'has_public_parking',
#        'is_parking_included_in_price', 'parking_price', 'is_orientation_north',
#        'is_orientation_west', 'is_orientation_south', 'is_orientation_east'],
#       dtype='object')

# %%
pd.set_option("display.max_row", 500)
db.subtitle.value_counts()
# Out:
# Chamartín, Madrid                           851
# Moncloa, Madrid                             771
# Chamberí, Madrid                            583
# Centro, Madrid                              552
# Hortaleza, Madrid                           503
# Barrio de Salamanca, Madrid                 457
# Fuencarral, Madrid                          383
# Malasaña-Universidad, Madrid                340
# Lavapiés-Embajadores, Madrid                319
# Tetuán, Madrid                              307
# Ensanche de Vallecas - La Gavia, Madrid     305
# Prosperidad, Madrid                         293
# Pueblo Nuevo, Madrid                        282
# Ciudad Lineal, Madrid                       280
# San Diego, Madrid                           268
# El Cañaveral - Los Berrocales, Madrid       266
# Argüelles, Madrid                           256
# San Isidro, Madrid                          255
# Cuatro Caminos, Madrid                      244
# Retiro, Madrid                              238
# Ventas, Madrid                              231
# Trafalgar, Madrid                           228
# San Andrés, Madrid                          219
# Peñagrande, Madrid                          216
# Almagro, Madrid                             216
# Vista Alegre, Madrid                        214
# Numancia, Madrid                            213
# Chueca-Justicia, Madrid                     213
# Bellas Vistas, Madrid                       208
# Valdeacederas, Madrid                       203
# Nuevos Ministerios-Ríos Rosas, Madrid       202
# Sanchinarro, Madrid                         202
# Gaztambide, Madrid                          201
# Carabanchel, Madrid                         200
# Puerta Bonita, Madrid                       198
# Bernabéu-Hispanoamérica, Madrid             191
# Puerta del Ángel, Madrid                    183
# Palacio, Madrid                             182
# Delicias, Madrid                            182
# Goya, Madrid                                181
# Abrantes, Madrid                            181
# Pacífico, Madrid                            175
# Conde Orgaz-Piovera, Madrid                 174
# Aravaca, Madrid                             172
# Pinar del Rey, Madrid                       170
# Arapiles, Madrid                            167
# El Viso, Madrid                             167
# Butarque, Madrid                            162
# Acacias, Madrid                             158
# Puente de Vallecas, Madrid                  158
# Casco Histórico de Vallecas, Madrid         158
# Cuzco-Castillejos, Madrid                   156
# Palomeras sureste, Madrid                   153
# Berruguete, Madrid                          153
# Opañel, Madrid                              152
# Vallehermoso, Madrid                        150
# Palos de Moguer, Madrid                     144
# Canillas, Madrid                            143
# Valdebebas - Valdefuentes, Madrid           142
# Ciudad Universitaria, Madrid                141
# Nueva España, Madrid                        141
# Palomeras Bajas, Madrid                     141
# Imperial, Madrid                            140
# Lucero, Madrid                              139
# Guindalera, Madrid                          139
# Almendrales, Madrid                         137
# Aluche, Madrid                              136
# Ibiza, Madrid                               135
# Villaverde, Madrid                          134
# Legazpi, Madrid                             133
# Los Rosales, Madrid                         133
# Chopera, Madrid                             132
# Valdezarza, Madrid                          131
# Moscardó, Madrid                            123
# Usera, Madrid                               122
# Buena Vista, Madrid                         120
# Quintana, Madrid                            116
# Adelfas, Madrid                             115
# Pilar, Madrid                               115
# Arganzuela, Madrid                          114
# Recoletos, Madrid                           113
# Comillas, Madrid                            112
# Castilla, Madrid                            111
# Entrevías, Madrid                           108
# Concepción, Madrid                          108
# Huertas-Cortes, Madrid                      106
# Las Tablas, Madrid                          103
# Costillares, Madrid                          99
# Estrella, Madrid                             97
# La Paz, Madrid                               93
# Los Ángeles, Madrid                          92
# Lista, Madrid                                91
# Latina, Madrid                               90
# Tres Olivos - Valverde, Madrid               89
# Ciudad Jardín, Madrid                        88
# Ventilla-Almenara, Madrid                    87
# Villa de Vallecas, Madrid                    87
# Pradolongo, Madrid                           86
# Mirasierra, Madrid                           82
# Águilas, Madrid                              81
# San Pascual, Madrid                          80
# Castellana, Madrid                           79
# Pau de Carabanchel, Madrid                   76
# Ambroz, Madrid                               75
# Portazgo, Madrid                             75
# San Fermín, Madrid                           75
# San Cristóbal, Madrid                        74
# Sol, Madrid                                  73
# Casco Histórico de Vicálvaro, Madrid         73
# Fontarrón, Madrid                            72
# Valdemarín, Madrid                           72
# Marroquina, Madrid                           69
# Los Cármenes, Madrid                         69
# Montecarmelo, Madrid                         67
# San Juan Bautista, Madrid                    65
# Casa de Campo, Madrid                        64
# Colina, Madrid                               64
# Palomas, Madrid                              63
# Orcasitas, Madrid                            62
# Jerónimos, Madrid                            61
# Vicálvaro, Madrid                            58
# Apóstol Santiago, Madrid                     54
# Santa Eugenia, Madrid                        54
# Campamento, Madrid                           51
# Zofío, Madrid                                51
# Fuente del Berro, Madrid                     50
# Virgen del Cortijo - Manoteras, Madrid       45
# Valdebernardo - Valderribas, Madrid          44
# El Plantío, Madrid                           44
# Vinateros, Madrid                            43
# 12 de Octubre-Orcasur, Madrid                40
# Moratalaz, Madrid                            40
# Media Legua, Madrid                          38
# Fuentelarreina, Madrid                       37
# Niño Jesús, Madrid                           34
# Atalaya, Madrid                              27
# Arroyo del Fresno, Madrid                    20
# Pavones, Madrid                              14
# El Pardo, Madrid                             12
# Alameda de Osuna, Madrid                     12
# Horcajo, Madrid                              11
# Barajas, Madrid                               7
# Campo de las Naciones-Corralejos, Madrid      6
# Casco Histórico de Barajas, Madrid            5
# Timón, Madrid                                 4
# Cuatro Vientos, Madrid                        2
# Name: subtitle, dtype: int64

# %%
db.energy_certificate.value_counts()
# Out:
# en trámite         10937
# no indicado         3669
# E                   2701
# D                   1121
# G                    894
# F                    674
# A                    618
# C                    580
# B                    452
# inmueble exento       96
# Name: energy_certificate, dtype: int64

# %%
dbrm= pd.read_csv("rentas_medias_cp.csv")
dbrm
# Out:
#     Año;"Periodo";"Parámetro";"Renta bruta media";"Renta disponible media"
# 0    2018;"Año";"02001-San Antonio Abad- La Pajarit...
# 1    2018;"Año";"02002-Parque Sur-Huerta de Marzo (...
# 2    2018;"Año";"02003-Franciscanos (Albacete)";"26...
# 3    2018;"Año";"02004-Fátima- Villacerrada (Albace...
# 4    2018;"Año";"02005-Industria- El Pilar- Feria- ...
# ..                                                 ...
# 616                                                ;;;
# 617                                                ;;;
# 618  Url:"https://www.epdata.es/buscador-renta-medi...
# 619  Titulo:"Buscador de renta media por códigos po...
# 620                                       Subtitulo:""
#
# [621 rows x 1 columns]

# %%
pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\aitor\anaconda3\lib\site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
